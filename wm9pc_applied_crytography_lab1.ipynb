# %% [markdown]
# <a href="https://colab.research.google.com/github/VanaheimD/Cryptography/blob/main/wm9pc_applied_crytography_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycryptodome
from Crypto.Random import get_random_bytes
import binascii
import base64
key = get_random_bytes(16) # 128-bit key
print("Hexadecimal:", binascii.hexlify(key).decode())
print("Base64:", base64.b64encode(key).decode())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 26.0 MB/s eta 0:00:00
# ...
# Hexadecimal: 9462d3af3531aab5b03015bcdbcf8803
# Base64: lGLTrzUxqrWwMBW828+IAw==

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad

key = b'ThisIsA16ByteKey'
cipher = AES.new(key, AES.MODE_ECB)
plaintext = b"hello, AES ECB!"
ciphertext = cipher.encrypt(pad(plaintext, AES.block_size))
print("Ciphertext:", ciphertext.hex())

decipher = AES.new(key,AES.MODE_ECB)
decrypted = unpad(decipher.decrypt(ciphertext),AES.block_size)
print("Decrypted:", decrypted.decode())
# Out:
# Ciphertext: 3e95316408a8c0fd29c6a06607dcdc43
# Decrypted: hello, AES ECB!

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad ,unpad
from Crypto.Random import get_random_bytes

key = get_random_bytes(16)
iv = get_random_bytes(16)
cipher = AES.new(key, AES.MODE_CBC, iv)
plaintext = b"hello, AES CBC!"
ciphertext = cipher.encrypt(pad(plaintext, AES.block_size))
print("Ciphertext:" , ciphertext.hex())

decipher = AES.new(key, AES.MODE_CBC, iv)
decrypted = unpad(decipher.decrypt(ciphertext), AES.block_size)
print("Decrypted:", decrypted.decode())
# Out:
# Ciphertext: 2920d808361a2ea22a3da0125f044d98
# Decrypted: hello, AES CBC!

# %%
def encrypt(input_file, output_file, key):
    from Crypto.Cipher import AES
    from Crypto.Util.Padding import pad
    from Crypto.Random import get_random_bytes

    iv = get_random_bytes(16)
    cipher = AES.new(key,AES.MODE_CBC,iv)

    with open(input_file, 'rb') as f:
      plaintext = f.read()
    ciphertext = cipher.encrypt(pad(plaintext,AES.block_size))

    with open(output_file, 'wb') as f:
      f.write(iv + ciphertext)

def decrypt(input_file, output_file, key):
  from Crypto.Cipher import AES
  from Crypto.Util.Padding import unpad

  with open(input_file, 'rb') as f:
    ciphertext = f.read

  with open(output_file, 'wb') as f:
    plaintext = unpad(cipher.decrypt(ciphertext),AES.block_size)
    f.write(plaintext)

# %%
plaintext = b"HELLOHELLOHELLO"
key = b"ThisIsA16ByteKey"

ecb_cipher = AES.new(key, AES.MODE_ECB)
ecb_ciphertext = ecb_cipher.encrypt(pad(plaintext, AES.block_size))
print("ECB ciphertext:", ecb_ciphertext.hex())

cbc_cipher = AES.new(key,AES.MODE_CBC)
cbc_ciphertext = cbc_cipher.encrypt(pad(plaintext, AES.block_size))
print("CBC ciphertext:", cbc_ciphertext.hex())
# Out:
# ECB ciphertext: c9ef21378e9387d1463cc4bab82b715c
# CBC ciphertext: 64faeacc121eede33a422c6ccd75c5f3
